# %% [markdown]
# # Introduction
#
# This is an interactive notebook containing code to run a CNN-LSTM model for video captioning. More information and credits can be found at our [Github](https://github.com/teresa-tommy/VideoCaptioningCapstone). To use the notebook, install the data files from our Github, or download data of your own and organize it as we did. Afterwards, run each of the cells in order, updating file paths as necessary. After successfully running the notebook, you will have generated a set of captions for the video dataset. If you would like to turn these captions into metrics, refer to our notebook, Metrics.ipynb, also linked in our [Github](https://github.com/teresa-tommy/VideoCaptioningCapstone).

# %% [markdown]
# ## Setup
# This note book was originally designed for use in Google Colab. If this notebook is running locally through Jupyter Notebooks or another tool, the cell below is not needed. Ensure all file paths are updated accordingly.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The following cells install all necessary dependencies and add the necessary import statements.

# %%
# !pip install tensorflow
# !pip install keras_preprocessing
# !pip install dill
# !pip install -r drive/MyDrive/KerasModel/requirements.txt
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: keras_preprocessing in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Collecting absl-py==0.11.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 1))
#   Using cached absl_py-0.11.0-py3-none-any.whl (127 kB)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.10/dist-packages (from -r drive/MyDrive/KerasModel/requirements.txt (line 2)) (1.6.3)
# Collecting cachetools==4.2.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 3))
#   Using cached cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting certifi==2020.12.5 (from -r drive/MyDrive/KerasModel/requirements.txt (line 4))
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Collecting chardet==4.0.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 5))
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting dill==0.3.3 (from -r drive/MyDrive/KerasModel/requirements.txt (line 6))
#   Using cached dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting flatbuffers==1.12 (from -r drive/MyDrive/KerasModel/requirements.txt (line 7))
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting future==0.18.2 (from -r drive/MyDrive/KerasModel/requirements.txt (line 8))
#   Using cached future-0.18.2.tar.gz (829 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gast==0.3.3 (from -r drive/MyDrive/KerasModel/requirements.txt (line 9))
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting google-auth==1.27.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 10))
#   Using cached google_auth-1.27.0-py2.py3-none-any.whl (135 kB)
# Collecting google-auth-oauthlib==0.4.2 (from -r drive/MyDrive/KerasModel/requirements.txt (line 11))
#   Using cached google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.10/dist-packages (from -r drive/MyDrive/KerasModel/requirements.txt (line 12)) (0.2.0)
# Collecting grpcio==1.32.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 13))
#   Using cached grpcio-1.32.0.tar.gz (20.8 MB)
#   Preparing metadata (setup.py) ... done
# Collecting h5py==2.10.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 14))
#   Using cached h5py-2.10.0.tar.gz (301 kB)
#   Preparing metadata (setup.py) ... done
# Collecting idna==2.10 (from -r drive/MyDrive/KerasModel/requirements.txt (line 15))
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata==3.7.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 16))
#   Using cached importlib_metadata-3.7.0-py3-none-any.whl (11 kB)
# Collecting joblib==1.0.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 17))
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting Keras==2.4.3 (from -r drive/MyDrive/KerasModel/requirements.txt (line 18))
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.10/dist-packages (from -r drive/MyDrive/KerasModel/requirements.txt (line 19)) (1.1.2)
# Collecting Markdown==3.3.4 (from -r drive/MyDrive/KerasModel/requirements.txt (line 20))
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting numpy==1.19.5 (from -r drive/MyDrive/KerasModel/requirements.txt (line 21))
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting oauthlib==3.1.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 22))
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from -r drive/MyDrive/KerasModel/requirements.txt (line 23)) (3.3.0)
# Collecting pip==21.0.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 24))
#   Using cached pip-21.0.1-py3-none-any.whl (1.5 MB)
# Collecting protobuf==3.15.3 (from -r drive/MyDrive/KerasModel/requirements.txt (line 25))
#   Using cached protobuf-3.15.3-py2.py3-none-any.whl (173 kB)
# Collecting pyasn1==0.4.8 (from -r drive/MyDrive/KerasModel/requirements.txt (line 26))
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules==0.2.8 (from -r drive/MyDrive/KerasModel/requirements.txt (line 27))
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests==2.25.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 28))
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting requests-oauthlib==1.3.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 29))
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa==4.7.2 (from -r drive/MyDrive/KerasModel/requirements.txt (line 30))
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting scipy==1.6.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 31))
#   Using cached scipy-1.6.1.tar.gz (27.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting setuptools==52.0.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 32))
#   Using cached setuptools-52.0.0-py3-none-any.whl (784 kB)
# Collecting six==1.15.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 33))
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorboard==2.4.1 (from -r drive/MyDrive/KerasModel/requirements.txt (line 34))
#   Using cached tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
# Collecting tensorboard-plugin-wit==1.8.0 (from -r drive/MyDrive/KerasModel/requirements.txt (line 35))
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# ERROR: Ignored the following versions that require a different python version: 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.1 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1)
# ERROR: No matching distribution found for tensorflow==2.4.1

# %%
import json
import random
import os
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
import cv2
import shutil
import functools
import operator
import os
import time
import os
from keras.layers import Input, LSTM, Dense
from keras.models import Model, load_model
import tensorflow.keras.preprocessing
import joblib

# %% [markdown]
# The next cells define and create a config containing parameters to be used throughout the rest of the notebook. Since we will only be testing a pre-trained model, the hyper-parameters do not need to be adjusted. The primary parameter of concern is the test_path, which should be a path to the directory of the testing data.

# %%
class Config:
    def __init__(self):
        self.train_path = "drive/MyDrive/KerasModel/data/training_data/"
        self.test_path = "drive/MyDrive/KerasModel/data/testing_data/"
        self.batch_size = 320
        self.learning_rate = 0.0007
        self.epochs = 150
        self.latent_dim = 512
        self.num_encoder_tokens = 4096
        self.num_decoder_tokens = 1500
        self.time_steps_encoder = 80
        self.max_probability = -1
        self.save_model_path = 'drive/MyDrive/KerasModel/model_final'
        self.validation_split = 0.15
        self.max_length = 10
        self.search_type = 'greedy'

# %%
config = Config()

# %% [markdown]
# ## Data Pre-processing
#
# The following cells define methods for feature extraction from the video data and run feature extraction on the requested dataset. If it already detects that a video has had features extracted already, the notebook will skip over them, which means you do not have to extract all the features in one session.

# %%
def video_to_frames(video, config):
    path = os.path.join(config.test_path, 'temporary_images')
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)
    video_path = os.path.join(config.test_path, 'video', video)
    count = 0
    image_list = []
    # Path to video file
    cap = cv2.VideoCapture(video_path)
    while cap.isOpened():
        ret, frame = cap.read()
        if ret is False:
            break
        cv2.imwrite(os.path.join(config.test_path, 'temporary_images', 'frame%d.jpg' % count), frame)
        image_list.append(os.path.join(config.test_path, 'temporary_images', 'frame%d.jpg' % count))
        count += 1

    cap.release()
    cv2.destroyAllWindows()
    return image_list

# %%
def model_cnn_load():
    model = VGG16(weights="imagenet", include_top=True, input_shape=(224, 224, 3))
    out = model.layers[-2].output
    model_final = Model(inputs=model.input, outputs=out)
    return model_final


def load_image(path):
    img = cv2.imread(path)
    img = cv2.resize(img, (224, 224))
    return img


def extract_features(video, model, config):
    """
    :param video: The video whose frames are to be extracted to convert into a numpy array
    :param model: the pretrained vgg16 model
    :return: numpy array of size 4096x80
    """
    video_id = video.split(".")[0]
    print(video_id)
    print(f'Processing video {video}')

    image_list = video_to_frames(video, config)
    samples = np.round(np.linspace(
        0, len(image_list) - 1, 80))
    image_list = [image_list[int(sample)] for sample in samples]
    images = np.zeros((len(image_list), 224, 224, 3))
    for i in range(len(image_list)):
        img = load_image(image_list[i])
        images[i] = img
    images = np.array(images)
    fc_feats = model.predict(images, batch_size=128)
    img_feats = np.array(fc_feats)
    # cleanup
    shutil.rmtree(os.path.join(config.test_path, 'temporary_images'))
    return img_feats


def extract_feats_pretrained_cnn(config):
    """
    saves the numpy features from all the videos
    """
    model = model_cnn_load()
    print('Model loaded')

    if not os.path.isdir(os.path.join(config.test_path, 'feat')):
        os.mkdir(os.path.join(config.test_path, 'feat'))

    i = 1

    video_list = os.listdir(os.path.join(config.test_path, 'video'))
    for video in video_list:
        print("video " + str(i))
        i = i + 1
        # outfile = os.path.join(test_path, 'feat', video.split(".")[0] + '.npy')
        # img_feats = extract_features(video, model)
        # np.save(outfile, img_feats)
        outfile = os.path.join(config.test_path, 'feat', video.split(".")[0] + '.avi.npy')
        print(outfile)
        if os.path.exists(outfile):
            print(f"Skipping video {video}, already processed")
            continue

        img_feats = extract_features(video, model, config)
        np.save(outfile, img_feats)

# %%
extract_feats_pretrained_cnn(config)
# Out:
# Model loaded
# video 1
# drive/MyDrive/KerasModel/data/testing_data/feat/klteYv1Uv9A_27_33.avi.npy
# klteYv1Uv9A_27_33
# Processing video klteYv1Uv9A_27_33.avi
# 1/1 [==============================] - 37s 37s/step
# video 2
# drive/MyDrive/KerasModel/data/testing_data/feat/j2Dhf-xFUxU_13_20.avi.npy
# j2Dhf-xFUxU_13_20
# Processing video j2Dhf-xFUxU_13_20.avi
# 1/1 [==============================] - 35s 35s/step
# video 3
# drive/MyDrive/KerasModel/data/testing_data/feat/UXs3eq68ZjE_250_255.avi.npy
# UXs3eq68ZjE_250_255
# Processing video UXs3eq68ZjE_250_255.avi
# 1/1 [==============================] - 33s 33s/step
# video 4
# drive/MyDrive/KerasModel/data/testing_data/feat/TZ860P4iTaM_15_28.avi.npy
# TZ860P4iTaM_15_28
# Processing video TZ860P4iTaM_15_28.avi
# 1/1 [==============================] - 36s 36s/step
# video 5
# drive/MyDrive/KerasModel/data/testing_data/feat/u4T76jsPin0_0_11.avi.npy
# u4T76jsPin0_0_11
# Processing video u4T76jsPin0_0_11.avi
# 1/1 [==============================] - 32s 32s/step
# video 6
# drive/MyDrive/KerasModel/data/testing_data/feat/WTf5EgVY5uU_124_128.avi.npy
# WTf5EgVY5uU_124_128
# Processing video WTf5EgVY5uU_124_128.avi
# 1/1 [==============================] - 37s 37s/step
# video 7
# drive/MyDrive/KerasModel/data/testing_data/feat/ZbtpcGi2DWY_161_170.avi.npy
# ZbtpcGi2DWY_161_170
# Processing video ZbtpcGi2DWY_161_170.avi
# 1/1 [==============================] - 35s 35s/step
# video 8
# drive/MyDrive/KerasModel/data/testing_data/feat/CGllPWAwmUo_1_15.avi.npy
# CGllPWAwmUo_1_15
# Processing video CGllPWAwmUo_1_15.avi
# 1/1 [==============================] - 32s 32s/step
# video 9
# drive/MyDrive/KerasModel/data/testing_data/feat/tcxhOGyrCtI_15_21.avi.npy
# tcxhOGyrCtI_15_21
# Processing video tcxhOGyrCtI_15_21.avi
# 1/1 [==============================] - 32s 32s/step
# video 10
# drive/MyDrive/KerasModel/data/testing_data/feat/s1ZABV7AQdA_38_48.avi.npy
# s1ZABV7AQdA_38_48
# Processing video s1ZABV7AQdA_38_48.avi
# 1/1 [==============================] - 31s 31s/step
# video 11
# drive/MyDrive/KerasModel/data/testing_data/feat/J---aiyznGQ_0_6.avi.npy
# J---aiyznGQ_0_6
# Processing video J---aiyznGQ_0_6.avi
# 1/1 [==============================] - 32s 32s/step
# video 12
# drive/MyDrive/KerasModel/data/testing_data/feat/N2Cm0SLr0ZE_18_29.avi.npy
# N2Cm0SLr0ZE_18_29
# Processing video N2Cm0SLr0ZE_18_29.avi
# 1/1 [==============================] - 32s 32s/step
# video 13
# drive/MyDrive/KerasModel/data/testing_data/feat/lo4KcsBN--A_0_10.avi.npy
# lo4KcsBN--A_0_10
# Processing video lo4KcsBN--A_0_10.avi
# 1/1 [==============================] - 32s 32s/step
# video 14
# drive/MyDrive/KerasModel/data/testing_data/feat/sJSmRik2c-c_1_7.avi.npy
# sJSmRik2c-c_1_7
# Processing video sJSmRik2c-c_1_7.avi
# 1/1 [==============================] - 31s 31s/step
# video 15
# drive/MyDrive/KerasModel/data/testing_data/feat/pW9DFPqoIsI_26_50.avi.npy
# pW9DFPqoIsI_26_50
# Processing video pW9DFPqoIsI_26_50.avi
# 1/1 [==============================] - 32s 32s/step
# video 16
# drive/MyDrive/KerasModel/data/testing_data/feat/RSx5G0_xH48_12_17.avi.npy
# RSx5G0_xH48_12_17
# Processing video RSx5G0_xH48_12_17.avi
# 1/1 [==============================] - 32s 32s/step
# video 17
# drive/MyDrive/KerasModel/data/testing_data/feat/ecm9gf2Pgkc_1_24.avi.npy
# ecm9gf2Pgkc_1_24
# Processing video ecm9gf2Pgkc_1_24.avi
# 1/1 [==============================] - 32s 32s/step
# video 18
# drive/MyDrive/KerasModel/data/testing_data/feat/cnsjm3fNEec_4_10.avi.npy
# cnsjm3fNEec_4_10
# Processing video cnsjm3fNEec_4_10.avi
# 1/1 [==============================] - 31s 31s/step
# video 19
# drive/MyDrive/KerasModel/data/testing_data/feat/zv2RIbUsnSw_335_341.avi.npy
# zv2RIbUsnSw_335_341
# Processing video zv2RIbUsnSw_335_341.avi
# 1/1 [==============================] - 31s 31s/step
# video 20
# drive/MyDrive/KerasModel/data/testing_data/feat/3qqEKTPxLNs_1_15.avi.npy
# 3qqEKTPxLNs_1_15
# Processing video 3qqEKTPxLNs_1_15.avi
# 1/1 [==============================] - 31s 31s/step
# video 21
# drive/MyDrive/KerasModel/data/testing_data/feat/aM-RcQj0a7I_37_55.avi.npy
# aM-RcQj0a7I_37_55
# Processing video aM-RcQj0a7I_37_55.avi
# 1/1 [==============================] - 32s 32s/step
# video 22
# drive/MyDrive/KerasModel/data/testing_data/feat/MTjrZthHwJQ_2_11.avi.npy
# MTjrZthHwJQ_2_11
# Processing video MTjrZthHwJQ_2_11.avi
# 1/1 [==============================] - 31s 31s/step
# video 23
# drive/MyDrive/KerasModel/data/testing_data/feat/88DOMJ11q2M_84_87.avi.npy
# 88DOMJ11q2M_84_87
# Processing video 88DOMJ11q2M_84_87.avi
# 1/1 [==============================] - 42s 42s/step
# video 24
# drive/MyDrive/KerasModel/data/testing_data/feat/71soiLO6I9U_15_24.avi.npy
# 71soiLO6I9U_15_24
# Processing video 71soiLO6I9U_15_24.avi
# 1/1 [==============================] - 32s 32s/step
# video 25
# drive/MyDrive/KerasModel/data/testing_data/feat/0lh_UWF9ZP4_27_31.avi.npy
# 0lh_UWF9ZP4_27_31
# Processing video 0lh_UWF9ZP4_27_31.avi
# 1/1 [==============================] - 33s 33s/step
# video 26
# drive/MyDrive/KerasModel/data/testing_data/feat/NUYu9c9XsgY_7_21.avi.npy
# NUYu9c9XsgY_7_21
# Processing video NUYu9c9XsgY_7_21.avi
# 1/1 [==============================] - 33s 33s/step
# video 27
# drive/MyDrive/KerasModel/data/testing_data/feat/g1Gldu1KS44_8_14.avi.npy
# g1Gldu1KS44_8_14
# Processing video g1Gldu1KS44_8_14.avi
# 1/1 [==============================] - 32s 32s/step
# video 28
# drive/MyDrive/KerasModel/data/testing_data/feat/8HB7ywgJuTg_131_142.avi.npy
# 8HB7ywgJuTg_131_142
# Processing video 8HB7ywgJuTg_131_142.avi
# 1/1 [==============================] - 32s 32s/step
# video 29
# drive/MyDrive/KerasModel/data/testing_data/feat/30GeJHYoerk_121_126.avi.npy
# 30GeJHYoerk_121_126
# Processing video 30GeJHYoerk_121_126.avi
# 1/1 [==============================] - 31s 31s/step
# video 30
# drive/MyDrive/KerasModel/data/testing_data/feat/inzk2fTUe1w_1_15.avi.npy
# inzk2fTUe1w_1_15
# Processing video inzk2fTUe1w_1_15.avi
# 1/1 [==============================] - 32s 32s/step
# video 31
# drive/MyDrive/KerasModel/data/testing_data/feat/qeKX-N1nKiM_0_5.avi.npy
# qeKX-N1nKiM_0_5
# Processing video qeKX-N1nKiM_0_5.avi
# 1/1 [==============================] - 31s 31s/step
# video 32
# drive/MyDrive/KerasModel/data/testing_data/feat/zulPFoY64wE_26_33.avi.npy
# zulPFoY64wE_26_33
# Processing video zulPFoY64wE_26_33.avi
# 1/1 [==============================] - 31s 31s/step
# video 33
# drive/MyDrive/KerasModel/data/testing_data/feat/qvg9eM4Hmzk_4_10.avi.npy
# qvg9eM4Hmzk_4_10
# Processing video qvg9eM4Hmzk_4_10.avi
# 1/1 [==============================] - 33s 33s/step
# video 34
# drive/MyDrive/KerasModel/data/testing_data/feat/xxHx6s_DbUo_216_222.avi.npy
# xxHx6s_DbUo_216_222
# Processing video xxHx6s_DbUo_216_222.avi
# 1/1 [==============================] - 33s 33s/step
# video 35
# drive/MyDrive/KerasModel/data/testing_data/feat/Cjf21Y19aUQ_82_86.avi.npy
# Cjf21Y19aUQ_82_86
# Processing video Cjf21Y19aUQ_82_86.avi
# 1/1 [==============================] - 31s 31s/step
# video 36
# drive/MyDrive/KerasModel/data/testing_data/feat/YmXCfQm0_CA_277_284.avi.npy
# YmXCfQm0_CA_277_284
# Processing video YmXCfQm0_CA_277_284.avi
# 1/1 [==============================] - 32s 32s/step
# video 37
# drive/MyDrive/KerasModel/data/testing_data/feat/7HcYJKMxpcg_20_28.avi.npy
# 7HcYJKMxpcg_20_28
# Processing video 7HcYJKMxpcg_20_28.avi
# 1/1 [==============================] - 32s 32s/step
# video 38
# drive/MyDrive/KerasModel/data/testing_data/feat/jbzaMtPYtl8_48_58.avi.npy
# jbzaMtPYtl8_48_58
# Processing video jbzaMtPYtl8_48_58.avi
# 1/1 [==============================] - 32s 32s/step
# video 39
# drive/MyDrive/KerasModel/data/testing_data/feat/uJPupV4oLZ0_4_12.avi.npy
# uJPupV4oLZ0_4_12
# Processing video uJPupV4oLZ0_4_12.avi
# 1/1 [==============================] - 36s 36s/step
# video 40
# drive/MyDrive/KerasModel/data/testing_data/feat/5HAf_INrFy0_3_25.avi.npy
# 5HAf_INrFy0_3_25
# Processing video 5HAf_INrFy0_3_25.avi
# 1/1 [==============================] - 33s 33s/step
# video 41
# drive/MyDrive/KerasModel/data/testing_data/feat/JntMAcTlOF0_50_70.avi.npy
# JntMAcTlOF0_50_70
# Processing video JntMAcTlOF0_50_70.avi
# 1/1 [==============================] - 31s 31s/step
# video 42
# drive/MyDrive/KerasModel/data/testing_data/feat/Fe4tO5vW9_E_64_70.avi.npy
# Fe4tO5vW9_E_64_70
# Processing video Fe4tO5vW9_E_64_70.avi
# 1/1 [==============================] - 32s 32s/step
# video 43
# drive/MyDrive/KerasModel/data/testing_data/feat/DhwrBs96Kgk_120_124.avi.npy
# DhwrBs96Kgk_120_124
# Processing video DhwrBs96Kgk_120_124.avi
# 1/1 [==============================] - 32s 32s/step
# video 44
# drive/MyDrive/KerasModel/data/testing_data/feat/WWf0Z6ak3Dg_5_15.avi.npy
# WWf0Z6ak3Dg_5_15
# Processing video WWf0Z6ak3Dg_5_15.avi
# 1/1 [==============================] - 31s 31s/step
# video 45
# drive/MyDrive/KerasModel/data/testing_data/feat/RZL9irxnhZ0_34_40.avi.npy
# RZL9irxnhZ0_34_40
# Processing video RZL9irxnhZ0_34_40.avi
# 1/1 [==============================] - 32s 32s/step
# video 46
# drive/MyDrive/KerasModel/data/testing_data/feat/PeUHy0A1GF0_114_121.avi.npy
# PeUHy0A1GF0_114_121
# Processing video PeUHy0A1GF0_114_121.avi
# 1/1 [==============================] - 32s 32s/step
# video 47
# drive/MyDrive/KerasModel/data/testing_data/feat/MrQd1zUVRUM_103_110.avi.npy
# MrQd1zUVRUM_103_110
# Processing video MrQd1zUVRUM_103_110.avi
# 1/1 [==============================] - 33s 33s/step
# video 48
# drive/MyDrive/KerasModel/data/testing_data/feat/qLwgb3F0aPU_298_305.avi.npy
# qLwgb3F0aPU_298_305
# Processing video qLwgb3F0aPU_298_305.avi
# 1/1 [==============================] - 33s 33s/step
# video 49
# drive/MyDrive/KerasModel/data/testing_data/feat/J_evFB7RIKA_104_120.avi.npy
# J_evFB7RIKA_104_120
# Processing video J_evFB7RIKA_104_120.avi
# 1/1 [==============================] - 32s 32s/step
# video 50
# drive/MyDrive/KerasModel/data/testing_data/feat/1Sp2__RCT0c_11_15.avi.npy
# 1Sp2__RCT0c_11_15
# Processing video 1Sp2__RCT0c_11_15.avi
# 1/1 [==============================] - 31s 31s/step
# video 51
# drive/MyDrive/KerasModel/data/testing_data/feat/Dgf0VHMEtNs_57_66.avi.npy
# Dgf0VHMEtNs_57_66
# Processing video Dgf0VHMEtNs_57_66.avi
# 1/1 [==============================] - 32s 32s/step
# video 52
# drive/MyDrive/KerasModel/data/testing_data/feat/mmSQTI6gMNQ_120_128.avi.npy
# mmSQTI6gMNQ_120_128
# Processing video mmSQTI6gMNQ_120_128.avi
# 1/1 [==============================] - 32s 32s/step
# video 53
# drive/MyDrive/KerasModel/data/testing_data/feat/N3A7944_UJw_63_70.avi.npy
# N3A7944_UJw_63_70
# Processing video N3A7944_UJw_63_70.avi
# 1/1 [==============================] - 33s 33s/step
# video 54
# drive/MyDrive/KerasModel/data/testing_data/feat/04Gt01vatkk_308_321.avi.npy
# 04Gt01vatkk_308_321
# Processing video 04Gt01vatkk_308_321.avi
# 1/1 [==============================] - 32s 32s/step
# video 55
# drive/MyDrive/KerasModel/data/testing_data/feat/Je3V7U5Ctj4_569_576.avi.npy
# Je3V7U5Ctj4_569_576
# Processing video Je3V7U5Ctj4_569_576.avi
# 1/1 [==============================] - 32s 32s/step
# video 56
# drive/MyDrive/KerasModel/data/testing_data/feat/HV12kTtdTT4_5_14.avi.npy
# HV12kTtdTT4_5_14
# Processing video HV12kTtdTT4_5_14.avi
# 1/1 [==============================] - 38s 38s/step
# video 57
# drive/MyDrive/KerasModel/data/testing_data/feat/v7iIZXtpIb8_5_15.avi.npy
# v7iIZXtpIb8_5_15
# Processing video v7iIZXtpIb8_5_15.avi
# 1/1 [==============================] - 33s 33s/step
# video 58
# drive/MyDrive/KerasModel/data/testing_data/feat/6q1dX6thX3E_286_295.avi.npy
# 6q1dX6thX3E_286_295
# Processing video 6q1dX6thX3E_286_295.avi
# 1/1 [==============================] - 32s 32s/step
# video 59
# drive/MyDrive/KerasModel/data/testing_data/feat/dfOuTx66bJU_34_39.avi.npy
# dfOuTx66bJU_34_39
# Processing video dfOuTx66bJU_34_39.avi
# 1/1 [==============================] - 32s 32s/step
# video 60
# drive/MyDrive/KerasModel/data/testing_data/feat/Jag7oTemldY_12_25.avi.npy
# Jag7oTemldY_12_25
# Processing video Jag7oTemldY_12_25.avi
# 1/1 [==============================] - 32s 32s/step
# video 61
# drive/MyDrive/KerasModel/data/testing_data/feat/f9Won2JpOEU_60_80.avi.npy
# f9Won2JpOEU_60_80
# Processing video f9Won2JpOEU_60_80.avi
# 1/1 [==============================] - 31s 31s/step
# video 62
# drive/MyDrive/KerasModel/data/testing_data/feat/q7pOFn8s4zc_263_273.avi.npy
# q7pOFn8s4zc_263_273
# Processing video q7pOFn8s4zc_263_273.avi
# 1/1 [==============================] - 32s 32s/step
# video 63
# drive/MyDrive/KerasModel/data/testing_data/feat/e-j59PqJjSM_405_416.avi.npy
# e-j59PqJjSM_405_416
# Processing video e-j59PqJjSM_405_416.avi
# 1/1 [==============================] - 32s 32s/step
# video 64
# drive/MyDrive/KerasModel/data/testing_data/feat/HAjwXjwN9-A_16_24.avi.npy
# HAjwXjwN9-A_16_24
# Processing video HAjwXjwN9-A_16_24.avi
# 1/1 [==============================] - 33s 33s/step
# video 65
# drive/MyDrive/KerasModel/data/testing_data/feat/jTnrm338_KY_34_42.avi.npy
# jTnrm338_KY_34_42
# Processing video jTnrm338_KY_34_42.avi
# 1/1 [==============================] - 31s 31s/step
# video 66
# drive/MyDrive/KerasModel/data/testing_data/feat/IhwPQL9dFYc_124_129.avi.npy
# IhwPQL9dFYc_124_129
# Processing video IhwPQL9dFYc_124_129.avi
# 1/1 [==============================] - 31s 31s/step
# video 67
# drive/MyDrive/KerasModel/data/testing_data/feat/04Gt01vatkk_248_265.avi.npy
# 04Gt01vatkk_248_265
# Processing video 04Gt01vatkk_248_265.avi
# 1/1 [==============================] - 32s 32s/step
# video 68
# drive/MyDrive/KerasModel/data/testing_data/feat/glrijRGnmc0_211_215.avi.npy
# glrijRGnmc0_211_215
# Processing video glrijRGnmc0_211_215.avi
# 1/1 [==============================] - 32s 32s/step
# video 69
# drive/MyDrive/KerasModel/data/testing_data/feat/7NNg0_n-bS8_21_30.avi.npy
# 7NNg0_n-bS8_21_30
# Processing video 7NNg0_n-bS8_21_30.avi
# 1/1 [==============================] - 32s 32s/step
# video 70
# drive/MyDrive/KerasModel/data/testing_data/feat/8MVo7fje_oE_125_130.avi.npy
# 8MVo7fje_oE_125_130
# Processing video 8MVo7fje_oE_125_130.avi
# 1/1 [==============================] - 32s 32s/step
# video 71
# drive/MyDrive/KerasModel/data/testing_data/feat/e-j59PqJjSM_50_98.avi.npy
# e-j59PqJjSM_50_98
# Processing video e-j59PqJjSM_50_98.avi
# 1/1 [==============================] - 36s 36s/step
# video 72
# drive/MyDrive/KerasModel/data/testing_data/feat/77iDIp40m9E_126_131.avi.npy
# 77iDIp40m9E_126_131
# Processing video 77iDIp40m9E_126_131.avi
# 1/1 [==============================] - 33s 33s/step
# video 73
# drive/MyDrive/KerasModel/data/testing_data/feat/UdcObAQ5OOM_15_30.avi.npy
# UdcObAQ5OOM_15_30
# Processing video UdcObAQ5OOM_15_30.avi
# 1/1 [==============================] - 32s 32s/step
# video 74
# drive/MyDrive/KerasModel/data/testing_data/feat/778mkceE0UQ_40_46.avi.npy
# 778mkceE0UQ_40_46
# Processing video 778mkceE0UQ_40_46.avi
# 1/1 [==============================] - 32s 32s/step
# video 75
# drive/MyDrive/KerasModel/data/testing_data/feat/k5OKBX2e7xA_19_32.avi.npy
# k5OKBX2e7xA_19_32
# Processing video k5OKBX2e7xA_19_32.avi
# 1/1 [==============================] - 32s 32s/step
# video 76
# drive/MyDrive/KerasModel/data/testing_data/feat/EpMuCrbxE8A_107_115.avi.npy
# EpMuCrbxE8A_107_115
# Processing video EpMuCrbxE8A_107_115.avi
# 1/1 [==============================] - 32s 32s/step
# video 77
# drive/MyDrive/KerasModel/data/testing_data/feat/wkgGxsuNVSg_34_41.avi.npy
# wkgGxsuNVSg_34_41
# Processing video wkgGxsuNVSg_34_41.avi
# 1/1 [==============================] - 31s 31s/step
# video 78
# drive/MyDrive/KerasModel/data/testing_data/feat/BtQtRGI0F2Q_15_20.avi.npy
# BtQtRGI0F2Q_15_20
# Processing video BtQtRGI0F2Q_15_20.avi
# 1/1 [==============================] - 32s 32s/step
# video 79
# drive/MyDrive/KerasModel/data/testing_data/feat/RjpbFlOHFps_8_25.avi.npy
# RjpbFlOHFps_8_25
# Processing video RjpbFlOHFps_8_25.avi
# 1/1 [==============================] - 32s 32s/step
# video 80
# drive/MyDrive/KerasModel/data/testing_data/feat/tJHUH9tpqPg_113_118.avi.npy
# tJHUH9tpqPg_113_118
# Processing video tJHUH9tpqPg_113_118.avi
# 1/1 [==============================] - 32s 32s/step
# video 81
# drive/MyDrive/KerasModel/data/testing_data/feat/5YJaS2Eswg0_22_26.avi.npy
# 5YJaS2Eswg0_22_26
# Processing video 5YJaS2Eswg0_22_26.avi
# 1/1 [==============================] - 33s 33s/step
# video 82
# drive/MyDrive/KerasModel/data/testing_data/feat/bqMmyY1ImkI_0_14.avi.npy
# bqMmyY1ImkI_0_14
# Processing video bqMmyY1ImkI_0_14.avi
# 1/1 [==============================] - 31s 31s/step
# video 83
# drive/MyDrive/KerasModel/data/testing_data/feat/6JnGBs88sL0_4_10.avi.npy
# 6JnGBs88sL0_4_10
# Processing video 6JnGBs88sL0_4_10.avi
# 1/1 [==============================] - 31s 31s/step
# video 84
# drive/MyDrive/KerasModel/data/testing_data/feat/sZf3VDsdDPM_107_114.avi.npy
# sZf3VDsdDPM_107_114
# Processing video sZf3VDsdDPM_107_114.avi
# 1/1 [==============================] - 34s 34s/step
# video 85
# drive/MyDrive/KerasModel/data/testing_data/feat/BAf3LXFUaGs_28_38.avi.npy
# BAf3LXFUaGs_28_38
# Processing video BAf3LXFUaGs_28_38.avi
# 1/1 [==============================] - 31s 31s/step
# video 86
# drive/MyDrive/KerasModel/data/testing_data/feat/0lh_UWF9ZP4_62_69.avi.npy
# 0lh_UWF9ZP4_62_69
# Processing video 0lh_UWF9ZP4_62_69.avi
# 1/1 [==============================] - 33s 33s/step
# video 87
# drive/MyDrive/KerasModel/data/testing_data/feat/mtrCf667KDk_134_176.avi.npy
# mtrCf667KDk_134_176
# Processing video mtrCf667KDk_134_176.avi
# 1/1 [==============================] - 37s 37s/step
# video 88
# drive/MyDrive/KerasModel/data/testing_data/feat/UbmZAe5u5FI_132_141.avi.npy
# UbmZAe5u5FI_132_141
# Processing video UbmZAe5u5FI_132_141.avi
# 1/1 [==============================] - 33s 33s/step
# video 89
# drive/MyDrive/KerasModel/data/testing_data/feat/He7Ge7Sogrk_47_70.avi.npy
# He7Ge7Sogrk_47_70
# Processing video He7Ge7Sogrk_47_70.avi
# 1/1 [==============================] - 32s 32s/step
# video 90
# drive/MyDrive/KerasModel/data/testing_data/feat/k06Ge9ANKM8_5_16.avi.npy
# k06Ge9ANKM8_5_16
# Processing video k06Ge9ANKM8_5_16.avi
# 1/1 [==============================] - 32s 32s/step
# video 91
# drive/MyDrive/KerasModel/data/testing_data/feat/4PcL6-mjRNk_11_18.avi.npy
# 4PcL6-mjRNk_11_18
# Processing video 4PcL6-mjRNk_11_18.avi
# 1/1 [==============================] - 31s 31s/step
# video 92
# drive/MyDrive/KerasModel/data/testing_data/feat/xCFCXzDUGjY_5_9.avi.npy
# xCFCXzDUGjY_5_9
# Processing video xCFCXzDUGjY_5_9.avi
# 1/1 [==============================] - 31s 31s/step
# video 93
# drive/MyDrive/KerasModel/data/testing_data/feat/n016q1w8Q30_2_11.avi.npy
# n016q1w8Q30_2_11
# Processing video n016q1w8Q30_2_11.avi
# 1/1 [==============================] - 32s 32s/step
# video 94
# drive/MyDrive/KerasModel/data/testing_data/feat/lw7pTwpx0K0_38_48.avi.npy
# lw7pTwpx0K0_38_48
# Processing video lw7pTwpx0K0_38_48.avi
# 1/1 [==============================] - 32s 32s/step
# video 95
# drive/MyDrive/KerasModel/data/testing_data/feat/ufFT2BWh3BQ_0_8.avi.npy
# ufFT2BWh3BQ_0_8
# Processing video ufFT2BWh3BQ_0_8.avi
# 1/1 [==============================] - 31s 31s/step
# video 96
# drive/MyDrive/KerasModel/data/testing_data/feat/shPymuahrsc_5_12.avi.npy
# shPymuahrsc_5_12
# Processing video shPymuahrsc_5_12.avi
# 1/1 [==============================] - 31s 31s/step
# video 97
# drive/MyDrive/KerasModel/data/testing_data/feat/ScdUht-pM6s_53_63.avi.npy
# ScdUht-pM6s_53_63
# Processing video ScdUht-pM6s_53_63.avi
# 1/1 [==============================] - 31s 31s/step
# video 98
# drive/MyDrive/KerasModel/data/testing_data/feat/XOAgUVVwKEA_8_20.avi.npy
# XOAgUVVwKEA_8_20
# Processing video XOAgUVVwKEA_8_20.avi
# 1/1 [==============================] - 31s 31s/step
# video 99
# drive/MyDrive/KerasModel/data/testing_data/feat/4xVGpDmA4lE_23_33.avi.npy
# 4xVGpDmA4lE_23_33
# Processing video 4xVGpDmA4lE_23_33.avi
# 1/1 [==============================] - 32s 32s/step
# video 100
# drive/MyDrive/KerasModel/data/testing_data/feat/rl1rVk_xIOs_1_16.avi.npy
# rl1rVk_xIOs_1_16
# Processing video rl1rVk_xIOs_1_16.avi
# 1/1 [==============================] - 31s 31s/step

# %% [markdown]
# ## Running the model
#
# The rest of the cells are responsible for defining the necessary methods for running the model and generating captions based on the previously extracted set of features.

# %%
def inference_model(config):
    """Returns the model that will be used for inference"""
    with open(os.path.join(config.save_model_path, 'tokenizer' + str(config.num_decoder_tokens)), 'rb') as file:
        tokenizer = joblib.load(file)
    # loading encoder model. This remains the same
    inf_encoder_model = load_model(os.path.join(config.save_model_path, 'encoder_model.h5'))

    # inference decoder model loading
    decoder_inputs = Input(shape=(None, config.num_decoder_tokens))
    decoder_dense = Dense(config.num_decoder_tokens, activation='softmax')
    decoder_lstm = LSTM(config.latent_dim, return_sequences=True, return_state=True)
    decoder_state_input_h = Input(shape=(config.latent_dim,))
    decoder_state_input_c = Input(shape=(config.latent_dim,))
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    inf_decoder_model = Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    inf_decoder_model.load_weights(os.path.join(config.save_model_path, 'decoder_model_weights.h5'))
    return tokenizer, inf_encoder_model, inf_decoder_model

# %%
class VideoDescriptionInference():
    """
            Initialize the parameters for the model
            """
    def __init__(self, config):
        self.latent_dim = config.latent_dim
        self.num_encoder_tokens = config.num_encoder_tokens
        self.num_decoder_tokens = config.num_decoder_tokens
        self.time_steps_encoder = config.time_steps_encoder
        self.max_probability = config.max_probability

        # models
        self.tokenizer, self.inf_encoder_model,  self.inf_decoder_model = inference_model(config)
        self.save_model_path = config.save_model_path
        self.test_path = config.test_path
        self.search_type = config.search_type

    def greedy_search(self, loaded_array):
        """

                :param f: the loaded numpy array after creating videos to frames and extracting features
                :return: the final sentence which has been predicted greedily
                """
        inv_map = self.index_to_word()
        states_value = self.inf_encoder_model.predict(loaded_array.reshape(-1, 80, 4096))
        target_seq = np.zeros((1, 1, 1500))
        sentence = ''
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        for i in range(15):
            output_tokens, h, c = self.inf_decoder_model.predict([target_seq] + states_value)
            states_value = [h, c]
            output_tokens = output_tokens.reshape(self.num_decoder_tokens)
            y_hat = np.argmax(output_tokens)
            if y_hat == 0:
                continue
            if inv_map[y_hat] is None:
                break
            else:
                sentence = sentence + inv_map[y_hat] + ' '
                target_seq = np.zeros((1, 1, 1500))
                target_seq[0, 0, y_hat] = 1
        return ' '.join(sentence.split()[:-1])

    def decode_sequence2bs(self, input_seq):
        states_value = self.inf_encoder_model.predict(input_seq)
        target_seq = np.zeros((1, 1, self.num_decoder_tokens))
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        self.beam_search(target_seq, states_value, [], [], 0)
        return decode_seq

    def beam_search(self, target_seq, states_value, prob, path, lens):
        """

                :param target_seq: the array that is fed into the model to predict the next word
                :param states_value: previous state that is fed into the lstm cell
                :param prob: probability of predicting a word
                :param path: list of words from each sentence
                :param lens: number of words
                :return: final sentence
                """
        global decode_seq
        node = 2
        output_tokens, h, c = self.inf_decoder_model.predict(
            [target_seq] + states_value)
        output_tokens = output_tokens.reshape(self.num_decoder_tokens)
        sampled_token_index = output_tokens.argsort()[-node:][::-1]
        states_value = [h, c]
        for i in range(node):
            if sampled_token_index[i] == 0:
                sampled_char = ''
            else:
                sampled_char = list(self.tokenizer.word_index.keys())[
                    list(self.tokenizer.word_index.values()).index(sampled_token_index[i])]
            MAX_LEN = 12
            if sampled_char != 'eos' and lens <= MAX_LEN:
                p = output_tokens[sampled_token_index[i]]
                if sampled_char == '':
                    p = 1
                prob_new = list(prob)
                prob_new.append(p)
                path_new = list(path)
                path_new.append(sampled_char)
                target_seq = np.zeros((1, 1, self.num_decoder_tokens))
                target_seq[0, 0, sampled_token_index[i]] = 1.
                self.beam_search(target_seq, states_value, prob_new, path_new, lens + 1)
            else:
                p = output_tokens[sampled_token_index[i]]
                prob_new = list(prob)
                prob_new.append(p)
                p = functools.reduce(operator.mul, prob_new, 1)
                if p > self.max_probability:
                    decode_seq = path
                    self.max_probability = p

    def decoded_sentence_tuning(self, decoded_sentence):
        decode_str = []
        filter_string = ['bos', 'eos']
        uni_gram = {}
        last_string = ""
        for idx2, c in enumerate(decoded_sentence):
            if c in uni_gram:
                uni_gram[c] += 1
            else:
                uni_gram[c] = 1
            if last_string == c and idx2 > 0:
                continue
            if c in filter_string:
                continue
            if len(c) > 0:
                decode_str.append(c)
            if idx2 > 0:
                last_string = c
        return decode_str

    def index_to_word(self):
        # inverts word tokenizer
        index_to_word = {value: key for key, value in self.tokenizer.word_index.items()}
        return index_to_word

    def get_test_data(self):
        """
        loads all the numpy files
        :return: two lists containing all the video arrays and the video Id
        """
        X_test = []
        X_test_filename = []
        with open(os.path.join(self.test_path, 'testing_id.txt')) as testing_file:
            lines = testing_file.readlines()
            for filename in lines:
                filename = filename.strip()
                f = np.load(os.path.join(self.test_path, 'feat', filename + '.npy'))
                X_test.append(f)
                X_test_filename.append(filename[:-4])
            X_test = np.array(X_test)
        return X_test, X_test_filename

    def test(self):
        """
            writes the captions of all the testing videos in a text file
        """
        X_test, X_test_filename = self.get_test_data()

        # generate inference test outputs
        # results will be saved to the file with the path stated below
        with open(os.path.join(self.test_path, 't_%s.txt' % self.search_type), 'w') as file:
            for idx, x in enumerate(X_test):
                file.write(X_test_filename[idx] + ',')
                if self.search_type is 'greedy':
                    start = time.time()
                    decoded_sentence = self.greedy_search(x.reshape(-1, 80, 4096))
                    file.write(decoded_sentence + ',{:.2f}'.format(time.time()-start))
                else:
                    start = time.time()
                    decoded_sentence = self.decode_sequence2bs(x.reshape(-1, 80, 4096))
                    decode_str = self.decoded_sentence_tuning(decoded_sentence)
                    for d in decode_str:
                        file.write(d + ' ')
                    file.write(',{:.2f}'.format(time.time() - start))
                file.write('\n')

                # re-init max prob
                self.max_probability = -1
# Out:
# <>:148: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:148: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-13-448678179ec6>:148: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.search_type is 'greedy':

# %%
video_to_text = VideoDescriptionInference(config)
video_to_text.test()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# ...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# ## References
#
# The above code was adapted from the following:
# - [Medium Article](https://medium.com/analytics-vidhya/video-captioning-with-keras-511984a2cfff)
# - [GitHub](https://github.com/Shreyz-max/Video-Captioning)
